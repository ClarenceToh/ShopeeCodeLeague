# %%
shopeeinput =['2',
        '3 6',
        'apple lettuce limes avocado',
        'onion cranberries apple limes',
        'escarole corn28corn apple lettuce limes avocado',
        'limes avocado',
        'apple lettuce',
        'limes',
        'apple',
        'app',
        'apple limes',
        '3 3',
        'apple iphone se 2',
        'iphone 11 max pro',
        'iphone 11 pro max',
        'apple iphone',
        'max pro',
        'iphone',
        '3 3',
        'apple iphone se 2',
        'iphone 11 max pro',
        'iphone 11 pro max',
        'apple iphone',
        'max pro',
        'iphone',
        '3 3',
        'apple iphone se 2',
        'iphone 11 max pro',
        'iphone 11 pro max',
        'apple iphone',
        'max pro',
        'iphone',
        '2',
        '3 6',
        'apple lettuce limes avocado',
        'onion cranberries apple limes',
        'escarole corn28corn apple lettuce limes avocado',
        'limes avocado',
        'apple lettuce',
        'limes',
        'apple',
        'app',
        'apple limes'
        ]

# %%
def search(input):
    casenum = int(input[0])
    def breaknum (string):
        N = int(string.split(' ')[0])
        Q = int(string.split(' ')[1])
        return N,Q
    def NQ(string):
        if len(string) == 3 and string[1] ==" " and string[0].isnumeric() and string[2].isnumeric():
            return(True)
    listofNQindex = []
    for i in range(len(input)):
        try:
          if NQ(input[i]) == True:
                listofNQindex.append(i)
        except:
            continue
    count = 1
    for i in listofNQindex:
        if len(listofNQindex) == int(input[0]):
            print("Case "+ str(count) +":")
            count+=1
            N = breaknum(input[i])[0]
            Q = breaknum(input[i])[1]
            listofnames = input[i+1: i+N+1]
            listofqueries = input[i+N+1: i+N+Q+1]
            listofnames = [ ' '+ item + ' ' for item in listofnames]
            listofqueries = [ ' '+ item + ' ' for item in listofqueries]
            dictOfqueries = { i : 0 for i in listofqueries }
            for name in listofnames:
                for query in listofqueries:
                    try:
                        if query in name:
                            dictOfqueries[query]+=1
                    except:
                        continue
            for query in listofqueries:
                print(dictOfqueries[query])
# print(search(shopeeinput))

# %%
input = shopeeinput
casenum = int(input[0])
def breaknum (string):
    N = int(string.split(' ')[0])
    Q = int(string.split(' ')[1])
    return N,Q
def NQ(string):
    if len(string) == 3 and string[1] ==" " and string[0].isnumeric() and string[2].isnumeric():
        return(True)
listofNQindex = []
for i in range(len(input)):
    try:
        if NQ(input[i]) == True:
            listofNQindex.append(i)
    except:
        continue
count = 1
for i in listofNQindex:
        print("Case "+ str(count) +":")
        count+=1
        N = breaknum(input[i])[0]
        Q = breaknum(input[i])[1]
        listofnames = input[i+1: i+N+1]
        listofqueries = input[i+N+1: i+N+Q+1]
        listofnames = [ ' '+ item + ' ' for item in listofnames]
        listofqueries = [ ' '+ item + ' ' for item in listofqueries]
        dictOfqueries = { i : 0 for i in listofqueries }
        for name in listofnames:
            for query in listofqueries:
                try:
                    if query in name:
                        dictOfqueries[query]+=1
                except:
                    continue
        for query in listofqueries:
            print(dictOfqueries[query])
# Out:
# Case 1:
# 2
# 2
# 3
# 3
# 0
# 1
# Case 2:
# 1
# 1
# 3
# Case 3:
# 1
# 1
# 3
# Case 4:
# 1
# 1
# 3
# Case 5:
# 2
# 2
# 3
# 3
# 0
# 1
